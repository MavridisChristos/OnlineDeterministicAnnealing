# %% [markdown]
# # Online Deterministic Annealing (ODA) for Custering
#
# > A general-purpose learning model designed to meet the needs of applications in which computational resources are limited, and robustness and interpretability are prioritized.
#
# > Constitutes an **online** prototype-based learning algorithm based on annealing optimization that is formulated as an recursive **gradient-free** stochastic approximation algorithm.
#
# > Can be viewed as an interpretable and progressively growing competitive-learning neural network model.
#
# > Christos Mavridis (<mavridis@umd.edu>)

# %%
# %matplotlib inline
from IPython.display import HTML

# Toggle on/off the raw code
# HTML('''<script>
# code_show=true; 
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# } 
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Toggle on/off the raw code."></form>''')

# %% [markdown]
# ## Import Modules

# %%
import pickle
import numpy as np

import os
import sys
sys.path.append('../OnlineDeterministicAnnealing/')

from oda import ODA 
import demo_domain

# For Plotting Figures horizontally
import matplotlib.pyplot as plt
import io
import base64
class FlowLayout(object):
    ''' A class / object to display plots in a horizontal / flow layout below a cell '''
    def __init__(self):
        # string buffer for the HTML: initially some CSS; images to be appended
        self.sHtml =  """
        <style>
        .floating-box {
        display: inline-block;
        margin: 10px;
        border: 3px solid #888888;  
        }
        </style>
        """

    def add_plot(self, oAxes):
        ''' Saves a PNG representation of a Matplotlib Axes object '''
        Bio=io.BytesIO() # bytes buffer for the plot
        fig = oAxes.get_figure()
        fig.canvas.print_png(Bio) # make a png of the plot in the buffer

        # encode the bytes as string using base 64 
        sB64Img = base64.b64encode(Bio.getvalue()).decode()
        self.sHtml+= (
            '<div class="floating-box">'+ 
            '<img src="data:image/png;base64,{}\n">'.format(sB64Img)+
            '</div>')

    def PassHtmlToCell(self):
        ''' Final step - display the accumulated HTML '''
        display(HTML(self.sHtml))

print('*** ODA Class Imported ***')
# Out:
# *** ODA Class Imported ***

# %% [markdown]
# ## Load Data

# %%
data_file = 'data'

with open(data_file+'.pkl', mode='rb') as file:
    train_data,train_labels,test_data,test_labels = pickle.load(file)

train_data = [[td[1]] for td in train_data]
test_data = [[td[1]] for td in test_data]

# for unsupervised learning
train_labels = [0 for i in range(len(train_labels))] 
test_labels = [0 for i in range(len(test_labels))] 
    
print(f'Training Data Format: [{train_data[0]}, ..., {train_data[-1]}]')
print(f'Training Labels Format: [{train_labels[0]}, ..., {train_labels[-1]}]')

oPlot = FlowLayout()
ax = demo_domain.show_data(train_data,train_labels,plot_fig=False,save_fig = False, title='Training Data')
oPlot.add_plot(ax)
ax = demo_domain.show_data(test_data,test_labels,plot_fig=False,save_fig = False, title='Testing Data')
oPlot.add_plot(ax)
oPlot.PassHtmlToCell()
# Out:
# Training Data Format: [[array([0.70373002, 0.291594  ])], ..., [array([0.80671487, 0.61023186])]]
# Training Labels Format: [0, ..., 0]
#         <style>
#         .floating-box {
#         display: inline-block;
#         margin: 10px;
#         border: 3px solid #888888;
#         }
#         </style>
#         <div class="floating-box"><img src="data:image/png;base64,...
# "></div><div class="floating-box"><img src="data:image/png;base64,...
# "></div>

# %% [markdown]
# ## Cost Function (Bregman Divergence)

# %%
# Bregman Divergence: Values in {'phi_Eucl', 'phi_KL'} (Squared Euclidean distance, KL divergence)
Bregman_phi = ['phi_Eucl']

# %% [markdown]
# ## Termination Criteria

# %%
# Minimum Termperature 
Tmin = [1e-4]

# Limit in node's children. After that stop growing
Kmax = [50]
# Limit in the number of convergent representations. (Developer Mode) 
timeline_limit = 1e3
# Desired training error. 
error_threshold = [0.0]
# Stop when reached 'error_threshold_count' times
error_threshold_count = [2]

# ODA vs Soft-Clustering vs LVQ
# Values in {0,1,2,3}
# 0:ODA update
# 1:ODA until Kmax. Then switch to 2:soft clustering with no perturbation/merging 
# 2:soft clustering with no perturbation/merging 
# 3: LVQ update (hard-clustering) with no perturbation/merging
lvq=[1]

# %% [markdown]
# ## Comments on Termination Criteria
#
# > These are predefined termination criteria.
#
# > Most of them do not require feedback (error calculation with respect to some dataset).
#
# > This is reminiscent of genetic algorithms.
#
# > Adaptive termination criteria with respect to feedback (e.g., relative change to error) can also be implemented.
#
# > For an application-specific extension please contact the author.

# %% [markdown]
# ## Load or Initialize Model

# %%
load_file = ''

# Load Existing ODA Model
if len(load_file)>0:

    with open(load_file+'.pkl', mode='rb') as file:
        clf = pickle.load(file)

    clf.load()

# Initialize ODA    
else:
    
    clf = ODA(train_data=train_data,train_labels=train_labels,Tmin=Tmin,Kmax=Kmax,lvq=lvq,error_threshold = [0.0])

print('*** ODA Model Initialized ***')
oPlot = FlowLayout()
ax = demo_domain.show_instance(clf=clf, instance=0, res=[1], plot_fig=False,save_fig = False)
oPlot.add_plot(ax)
oPlot.PassHtmlToCell()
print('(Ignore zero error text in the top right corner. It is just not quantified during initialization.)')
# Out:
# *** ODA Model Initialized ***
#         <style>
#         .floating-box {
#         display: inline-block;
#         margin: 10px;
#         border: 3px solid #888888;
#         }
#         </style>
#         <div class="floating-box"><img src="data:image/png;base64,...
# "></div>
# (Ignore zero error text in the top right corner. It is just not quantified during initialization.)

# %% [markdown]
# ## Fit Model

# %%
print('*** ODA ***')

clf.fit(test_data=test_data,test_labels=test_labels)

print('*** ODA ***')
accuTrain = clf.score(train_data, train_labels)
accuTest = clf.score(test_data, test_labels)
print(f'Train Ave. Distortion: {accuTrain}') 
print(f'Test Ave. Distortion: {accuTest}')    
print(f'Running time: {np.sum(clf.myTime):.1f}s')
# Out:
# *** ODA ***
# 2 -- ID: [0]: Samples: 6(+6): T = 0.9000, K = 1, treeK = 1, [+0.0s]
# Train Error: 0.0990
# Test Error: 0.1120
# 3 -- ID: [0]: Samples: 40(+34): T = 0.0900, K = 1, treeK = 1, [+0.0s]
# Train Error: 0.0847
# Test Error: 0.0929
# 4 -- ID: [0]: Samples: 85(+45): T = 0.0450, K = 1, treeK = 1, [+0.0s]
# Train Error: 0.0902
# Test Error: 0.0918
# 5 -- ID: [0]: Samples: 133(+48): T = 0.0360, K = 2, treeK = 2, [+0.0s]
# Train Error: 0.0428
# Test Error: 0.0451
# 6 -- ID: [0]: Samples: 212(+79): T = 0.0288, K = 3, treeK = 3, [+0.0s]
# Train Error: 0.0395
# Test Error: 0.0334
# 7 -- ID: [0]: Samples: 251(+39): T = 0.0230, K = 4, treeK = 4, [+0.0s]
# Train Error: 0.0187
# Test Error: 0.0181
# 8 -- ID: [0]: Samples: 328(+77): T = 0.0184, K = 4, treeK = 4, [+0.0s]
# Train Error: 0.0172
# Test Error: 0.0166
# 9 -- ID: [0]: Samples: 415(+87): T = 0.0147, K = 5, treeK = 5, [+0.0s]
# Train Error: 0.0103
# Test Error: 0.0108
# 10 -- ID: [0]: Samples: 520(+105): T = 0.0118, K = 5, treeK = 5, [+0.0s]
# Train Error: 0.0110
# Test Error: 0.0103
# 11 -- ID: [0]: Samples: 614(+94): T = 0.0094, K = 5, treeK = 5, [+0.0s]
# Train Error: 0.0081
# Test Error: 0.0084
# 12 -- ID: [0]: Samples: 661(+47): T = 0.0075, K = 5, treeK = 5, [+0.0s]
# Train Error: 0.0087
# Test Error: 0.0087
# 13 -- ID: [0]: Samples: 797(+136): T = 0.0060, K = 6, treeK = 6, [+0.0s]
# Train Error: 0.0076
# Test Error: 0.0075
# 14 -- ID: [0]: Samples: 943(+146): T = 0.0048, K = 5, treeK = 5, [+0.0s]
# Train Error: 0.0085
# Test Error: 0.0090
# 15 -- ID: [0]: Samples: 1097(+154): T = 0.0039, K = 8, treeK = 8, [+0.0s]
# Train Error: 0.0061
# Test Error: 0.0067
# 16 -- ID: [0]: Samples: 1248(+151): T = 0.0031, K = 10, treeK = 10, [+0.1s]
# Train Error: 0.0051
# Test Error: 0.0058
# 17 -- ID: [0]: Samples: 1600(+352): T = 0.0025, K = 14, treeK = 14, [+0.2s]
# Train Error: 0.0038
# Test Error: 0.0044
# 18 -- ID: [0]: Samples: 1912(+312): T = 0.0020, K = 22, treeK = 22, [+0.3s]
# Train Error: 0.0026
# Test Error: 0.0031
# 19 -- ID: [0]: Samples: 2486(+574): T = 0.0016, K = 31, treeK = 31, [+1.4s]
# Train Error: 0.0019
# Test Error: 0.0026
# 20 -- ID: [0]: Samples: 3201(+715): T = 0.0013, K = 41, treeK = 41, [+3.3s]
# Train Error: 0.0014
# Test Error: 0.0019
# --- Keeping K=41 codevectors.
# 21 -- ID: [0]: Samples: 3995(+794): T = 0.0013, K = 41, treeK = 41, [+6.1s]
# 22 -- ID: [0]: Samples: 4501(+506): T = 0.0010, K = 41, treeK = 41, [+1.1s]
# Train Error: 0.0014
# Test Error: 0.0019
# 23 -- ID: [0]: Samples: 5159(+658): T = 0.0008, K = 41, treeK = 41, [+1.5s]
# Train Error: 0.0014
# Test Error: 0.0018
# 24 -- ID: [0]: Samples: 5915(+756): T = 0.0006, K = 41, treeK = 41, [+1.8s]
# Train Error: 0.0014
# Test Error: 0.0021
# 25 -- ID: [0]: Samples: 6424(+509): T = 0.0005, K = 41, treeK = 41, [+1.1s]
# Train Error: 0.0014
# Test Error: 0.0019
# 26 -- ID: [0]: Samples: 7122(+698): T = 0.0004, K = 41, treeK = 41, [+1.5s]
# Train Error: 0.0013
# Test Error: 0.0019
# 27 -- ID: [0]: Samples: 7759(+637): T = 0.0003, K = 41, treeK = 41, [+1.4s]
# Train Error: 0.0013
# Test Error: 0.0019
# 28 -- ID: [0]: Samples: 8398(+639): T = 0.0003, K = 41, treeK = 41, [+1.4s]
# Train Error: 0.0012
# Test Error: 0.0019
# 29 -- ID: [0]: Samples: 9057(+659): T = 0.0002, K = 41, treeK = 41, [+1.4s]
# Train Error: 0.0013
# Test Error: 0.0021
# 30 -- ID: [0]: Samples: 10131(+1074): T = 0.0002, K = 41, treeK = 41, [+2.3s]
# Train Error: 0.0013
# Test Error: 0.0019
# 31 -- ID: [0]: Samples: 11089(+958): T = 0.0001, K = 41, treeK = 41, [+2.1s]
# Train Error: 0.0013
# Test Error: 0.0018
# 32 -- ID: [0]: Samples: 11749(+660): T = 0.0001, K = 41, treeK = 41, [+1.5s]
# Train Error: 0.0013
# Test Error: 0.0017
# 33 -- ID: [0]: Samples: 13009(+1260): T = 0.0001, K = 41, treeK = 41, [+2.7s]
# Train Error: 0.0012
# Test Error: 0.0019
# --- Minimum temperature reached. ---
# ID: [0]: Trained
# *** ODA ***
# Train Ave. Distortion: 0.0012335459704165342
# Test Ave. Distortion: 0.0019211457335238864
# Running time: 31.6s

# %% [markdown]
# ## Plot Training Curve

# %%
plot_curves = True

if clf.keepscore>1 and plot_curves:
    oPlot = FlowLayout()
    ax = clf.plot_curve('.', show = False, save = False)
    oPlot.add_plot(ax)
    oPlot.PassHtmlToCell()
# Out:
#         <style>
#         .floating-box {
#         display: inline-block;
#         margin: 10px;
#         border: 3px solid #888888;
#         }
#         </style>
#         <div class="floating-box"><img src="data:image/png;base64,...
# "></div>

# %% [markdown]
# ## Show Domain

# %%
show_domain = True
res = [1]

if show_domain:
    print('*** Plotting Domain ***')
    if len(res)<2:
        oPlot = FlowLayout()
        for i in [2,3,8,12,15,18,25,31]:
            ax = demo_domain.show_instance(clf=clf, instance = i, res=res, plot_fig=False, save_fig = False)
            oPlot.add_plot(ax)
        oPlot.PassHtmlToCell()
    else:
        axs = demo_domain.show_resolutions(clf=clf, res=res, plot_fig=False, save_fig = False)
        oPlot = FlowLayout()
        for ax in axs:
            oPlot.add_plot(ax)
        oPlot.PassHtmlToCell()
        
print('*** All Done ***')
# Out:
# *** Plotting Domain ***
#         <style>
#         .floating-box {
#         display: inline-block;
#         margin: 10px;
#         border: 3px solid #888888;
#         }
#         </style>
#         <div class="floating-box"><img src="data:image/png;base64,...
# "></div><div class="floating-box"><img src="data:image/png;base64,...
# "></div><div class="floating-box"><img src="data:image/png;base64,...
# "></div><div class="floating-box"><img src="data:image/png;base64,...
# "></div><div class="floating-box"><img src="data:image/png;base64,...
# "></div><div class="floating-box"><img src="data:image/png;base64,...
# "></div><div class="floating-box"><img src="data:image/png;base64,...
# "></div><div class="floating-box"><img src="data:image/png;base64,...
# "></div>
# *** All Done ***

# %% [markdown]
# # Takeaways:
#
# ## [1] Emphasis to areas with higher probability density
# - Progressively finer partition of the data space
# - Consistent density estimator in the limit $K\rightarrow \infty$
#
# ## [2] Trade-off between Performance and Complexity
# - No need to pre-define number of clusters $K$ (compare to k-means)
# - Especially useful in communication and compression applications and embedded CPS systems
#
# ## [3] Annealing helps avoid poor local minima
# - Compare to k-means, vector quantization, etc.
#
# ## [4] Online Approach
# - Update representation with each observation (compare to k-means, deterministic annealing)
# - Needs less observations than batch algorithms (compare to k-means, deterministic annealing)
#
# ## [5] General Dissimilarity Measures
# - Beyond distance measures (compare to k-means)
# - Works with any Bregman divergence (squared Euclidean distance, KL divergence, etc.)
# - Can compare distributions, functions, etc.
# - Can work with categorical values
#
# ## [6] Can we alleviate quadratic complexity $O(K^2)$?
# - See Tree-Structured Version below

# %% [markdown]
# ## Advanced Parameters (Developer Mode)

# %% [markdown]
# ### Temperature Schedule

# %%
# lambda max values in [0,1]. T = (1-lambda)/lambda
Tmax = [0.9]

# T' = gamma * T
gamma_steady = [0.8] 
# Initial updates can be set to reduce faster
gamma_schedule = [[0.1,0.5]]

# %% [markdown]
# ### Regularization

# %%
# Perturb (dublicate) existing codevectors 
# Parameter delta = d_phi(mu, mu+'delta')/T: 
perturb_param = [1e-1]
# Threshold to find merged (effective) codevectors
# Parameter e_n = d_phi(mu, mu+'effective_neighborhood')/T
effective_neighborhood = [1e-0]
# Parameter e_r: threshold to find idle codevectors
py_cut = [1e-6]

# %% [markdown]
# ### Convergence Parameters

# %%
# Parameter e_c =  d_phi(mu, mu+'em_convergence')/T
em_convergence = [1e-1]
# Convergece when d_phi(mu',mu) < e_c * (1+bb_init)/(1+bb) for 'convergence_counter_threshold' times
convergence_counter_threshold = [5]
# After 'stop_separation' loops, gibbs probabilities consider all codevectors regardless of class 
stop_separation = [1e6-1] 
# Custom number of loops until convergence is considered true (overwrites e_c) (Developer mode)
convergence_loops = [0]
# Initial bb value for stochastic approximation stepsize: 1/(bb+1)
bb_init = [0.9]
# bb+=bb_step
bb_step = [0.9]

# %% [markdown]
# ### Verbose

# %%
# Values in {0,1,2,3}    
# 0: don't compute or show score
# 1: compute and show score only on tree node splits 
# 2: compute score after every SA convergence and use it as a stopping criterion
# 3: compute and show score after every SA convergence and use it as a stopping criterion
keepscore = 3

# %% [markdown]
# ### Numba Jit

# %%
# Using jit/python for Bregman divergences
jit = True

# %% [markdown]
# # Tree-Structured ODA

# %% [markdown]
# ## Data

# %%
# Tree Layers: Up to 3 layers
res=[1,1,1]

with open(data_file+'.pkl', mode='rb') as file:
    train_data,train_labels,test_data,test_labels = pickle.load(file)
    
# Resolutions
train_data = [[td[r] for r in res] for td in train_data]
test_data = [[td[r] for r in res] for td in test_data]

# for unsupervised learning
train_labels = [0 for i in range(len(train_labels))] 
test_labels = [0 for i in range(len(test_labels))] 

print(f'Training Data Format: [{train_data[0]}, ..., {train_data[-1]}]')
# Out:
# Training Data Format: [[array([0.70373002, 0.291594  ]), array([0.70373002, 0.291594  ]), array([0.70373002, 0.291594  ])], ..., [array([0.80671487, 0.61023186]), array([0.80671487, 0.61023186]), array([0.80671487, 0.61023186])]]

# %% [markdown]
# ## Growing Criteria

# %%
## Stop each layer after reaching predefined error
error_threshold = [0.0]
## Stop each layer at predefined number of children
Kmax = [5, 5, 5]
## Stop each layer at predefined temperature levels
Tmax = [0.9,1e-2,1e-3]
Tmin = [1e-2,1e-3,5*1e-4]
gamma_schedule = [[0.1,0.5],[],[]]

clf = ODA(train_data=train_data,train_labels=train_labels,error_threshold=error_threshold,
         Kmax=Kmax,Tmax=Tmax,Tmin=Tmin,gamma_schedule=gamma_schedule)

print('*** Tree-Structured ODA Initialized***')
# demo_domain.data(clf=clf, res=[1], plot_fig=True,save_fig = False)
# Out:
# *** Tree-Structured ODA Initialized***

# %% [markdown]
# ## Comments on Growing/Splitting Criteria
#
# > These are predefined termination criteria.
#
# > Most of them do not require feedback (error calculation with respect to some dataset).
#
# > This is reminiscent of genetic algorithms.
#
# > Adaptive termination criteria with respect to feedback (e.g., relative change to error) can also be implemented.
#
# > For an application-specific extension please contact the author.

# %% [markdown]
# ## Fit Tree-Structured ODA

# %%
print('*** ODA ***')

clf.fit(test_data=test_data,test_labels=test_labels)

print('*** ODA ***')
accuTrain = clf.score(train_data, train_labels)
accuTest = clf.score(test_data, test_labels)
print(f'Ave. Distortion: {accuTrain}') 
print(f'Ave. Distortion: {accuTest}')    
print(f'Running time: {np.sum(clf.myTime):.1f}s')
# Out:
# *** ODA ***
# 2 -- ID: [0]: Samples: 6(+6): T = 0.9000, K = 1, treeK = 1, [+0.0s]
# Train Error: 0.1094
# Test Error: 0.1199
# 3 -- ID: [0]: Samples: 40(+34): T = 0.0900, K = 1, treeK = 1, [+0.0s]
# Train Error: 0.0850
# Test Error: 0.0938
# 4 -- ID: [0]: Samples: 81(+41): T = 0.0450, K = 1, treeK = 1, [+0.0s]
# Train Error: 0.0990
# Test Error: 0.0977
# 5 -- ID: [0]: Samples: 130(+49): T = 0.0360, K = 2, treeK = 2, [+0.0s]
# Train Error: 0.0430
# Test Error: 0.0457
# 6 -- ID: [0]: Samples: 209(+79): T = 0.0288, K = 3, treeK = 3, [+0.0s]
# Train Error: 0.0362
# Test Error: 0.0315
# 7 -- ID: [0]: Samples: 294(+85): T = 0.0230, K = 3, treeK = 3, [+0.0s]
# Train Error: 0.0306
# Test Error: 0.0287
# 8 -- ID: [0]: Samples: 374(+80): T = 0.0184, K = 5, treeK = 5, [+0.0s]
# Train Error: 0.0100
# Test Error: 0.0104
# 9 -- ID: [0]: Samples: 464(+90): T = 0.0147, K = 5, treeK = 5, [+0.0s]
# Train Error: 0.0085
# Test Error: 0.0086
# 10 -- ID: [0]: Samples: 560(+96): T = 0.0118, K = 5, treeK = 5, [+0.0s]
# Train Error: 0.0081
# Test Error: 0.0082
# 11 -- ID: [0]: Samples: 635(+75): T = 0.0094, K = 5, treeK = 5, [+0.0s]
# Train Error: 0.0079
# Test Error: 0.0078
# --- Minimum temperature reached. ---
# ID: [0]: Trained. Splitting..
# 12 -- ID: [0, 3]: Samples: 14(+14): T = 0.0100, K = 1, treeK = 5, [+0.0s]
# Train Error: 0.0078
# Test Error: 0.0077
# 13 -- ID: [0, 4]: Samples: 21(+21): T = 0.0100, K = 2, treeK = 6, [+0.0s]
# Train Error: 0.0078
# Test Error: 0.0076
# 14 -- ID: [0, 2]: Samples: 24(+24): T = 0.0100, K = 2, treeK = 7, [+0.0s]
# Train Error: 0.0077
# Test Error: 0.0076
# 15 -- ID: [0, 1]: Samples: 21(+21): T = 0.0100, K = 2, treeK = 8, [+0.0s]
# Train Error: 0.0079
# Test Error: 0.0077
# 16 -- ID: [0, 0]: Samples: 21(+21): T = 0.0100, K = 2, treeK = 9, [+0.0s]
# Train Error: 0.0078
# Test Error: 0.0077
# 17 -- ID: [0, 3]: Samples: 32(+18): T = 0.0080, K = 1, treeK = 9, [+0.0s]
# Train Error: 0.0082
# Test Error: 0.0082
# 18 -- ID: [0, 4]: Samples: 46(+25): T = 0.0080, K = 2, treeK = 9, [+0.0s]
# Train Error: 0.0082
# Test Error: 0.0084
# 19 -- ID: [0, 1]: Samples: 49(+28): T = 0.0080, K = 2, treeK = 9, [+0.0s]
# Train Error: 0.0081
# Test Error: 0.0083
# 20 -- ID: [0, 3]: Samples: 54(+22): T = 0.0064, K = 1, treeK = 9, [+0.0s]
# Train Error: 0.0077
# Test Error: 0.0079
# 21 -- ID: [0, 0]: Samples: 44(+23): T = 0.0080, K = 2, treeK = 9, [+0.0s]
# Train Error: 0.0079
# Test Error: 0.0080
# 22 -- ID: [0, 2]: Samples: 47(+23): T = 0.0080, K = 2, treeK = 9, [+0.1s]
# Train Error: 0.0083
# Test Error: 0.0085
# 23 -- ID: [0, 4]: Samples: 65(+19): T = 0.0064, K = 2, treeK = 9, [+0.0s]
# Train Error: 0.0083
# Test Error: 0.0085
# 24 -- ID: [0, 0]: Samples: 62(+18): T = 0.0064, K = 2, treeK = 9, [+0.0s]
# Train Error: 0.0081
# Test Error: 0.0085
# 25 -- ID: [0, 3]: Samples: 82(+28): T = 0.0051, K = 1, treeK = 9, [+0.0s]
# Train Error: 0.0082
# Test Error: 0.0084
# *** Idle Codevector Pruned ***
# 26 -- ID: [0, 2]: Samples: 80(+33): T = 0.0064, K = 1, treeK = 8, [+0.0s]
# Train Error: 0.0088
# Test Error: 0.0090
# *** Idle Codevector Pruned ***
# 27 -- ID: [0, 1]: Samples: 90(+41): T = 0.0064, K = 1, treeK = 7, [+0.1s]
# Train Error: 0.0090
# Test Error: 0.0092
# *** Idle Codevector Pruned ***
# 28 -- ID: [0, 0]: Samples: 89(+27): T = 0.0051, K = 1, treeK = 6, [+0.0s]
# Train Error: 0.0090
# Test Error: 0.0091
# *** Idle Codevector Pruned ***
# 29 -- ID: [0, 4]: Samples: 89(+24): T = 0.0051, K = 1, treeK = 5, [+0.1s]
# Train Error: 0.0090
# Test Error: 0.0091
# 30 -- ID: [0, 3]: Samples: 103(+21): T = 0.0041, K = 1, treeK = 5, [+0.0s]
# Train Error: 0.0091
# Test Error: 0.0092
# 31 -- ID: [0, 4]: Samples: 117(+28): T = 0.0041, K = 1, treeK = 5, [+0.0s]
# Train Error: 0.0092
# Test Error: 0.0091
# 32 -- ID: [0, 1]: Samples: 116(+26): T = 0.0051, K = 1, treeK = 5, [+0.0s]
# Train Error: 0.0090
# Test Error: 0.0090
# 33 -- ID: [0, 0]: Samples: 119(+30): T = 0.0041, K = 1, treeK = 5, [+0.0s]
# Train Error: 0.0090
# Test Error: 0.0091
# 34 -- ID: [0, 2]: Samples: 114(+34): T = 0.0051, K = 1, treeK = 5, [+0.1s]
# Train Error: 0.0083
# Test Error: 0.0083
# 35 -- ID: [0, 3]: Samples: 133(+30): T = 0.0033, K = 1, treeK = 5, [+0.0s]
# Train Error: 0.0085
# Test Error: 0.0086
# 36 -- ID: [0, 4]: Samples: 148(+31): T = 0.0033, K = 2, treeK = 6, [+0.0s]
# Train Error: 0.0079
# Test Error: 0.0083
# 37 -- ID: [0, 0]: Samples: 154(+35): T = 0.0033, K = 1, treeK = 6, [+0.0s]
# Train Error: 0.0080
# Test Error: 0.0083
# 38 -- ID: [0, 1]: Samples: 156(+40): T = 0.0041, K = 1, treeK = 6, [+0.0s]
# Train Error: 0.0082
# Test Error: 0.0085
# 39 -- ID: [0, 2]: Samples: 143(+29): T = 0.0041, K = 1, treeK = 6, [+0.0s]
# Train Error: 0.0083
# Test Error: 0.0086
# 40 -- ID: [0, 3]: Samples: 171(+38): T = 0.0026, K = 2, treeK = 7, [+0.0s]
# Train Error: 0.0076
# Test Error: 0.0079
# 41 -- ID: [0, 0]: Samples: 198(+44): T = 0.0026, K = 2, treeK = 8, [+0.0s]
# Train Error: 0.0069
# Test Error: 0.0072
# 42 -- ID: [0, 1]: Samples: 198(+42): T = 0.0033, K = 1, treeK = 8, [+0.0s]
# Train Error: 0.0070
# Test Error: 0.0073
# 43 -- ID: [0, 4]: Samples: 198(+50): T = 0.0026, K = 2, treeK = 8, [+0.1s]
# Train Error: 0.0070
# Test Error: 0.0072
# 44 -- ID: [0, 2]: Samples: 199(+56): T = 0.0033, K = 2, treeK = 9, [+0.1s]
# Train Error: 0.0060
# Test Error: 0.0060
# 45 -- ID: [0, 3]: Samples: 228(+57): T = 0.0021, K = 4, treeK = 11, [+0.1s]
# Train Error: 0.0056
# Test Error: 0.0055
# 46 -- ID: [0, 1]: Samples: 254(+56): T = 0.0026, K = 2, treeK = 12, [+0.0s]
# Train Error: 0.0047
# Test Error: 0.0050
# 47 -- ID: [0, 4]: Samples: 253(+55): T = 0.0021, K = 3, treeK = 13, [+0.0s]
# Train Error: 0.0044
# Test Error: 0.0047
# 48 -- ID: [0, 0]: Samples: 274(+76): T = 0.0021, K = 3, treeK = 14, [+0.1s]
# Train Error: 0.0042
# Test Error: 0.0043
# 49 -- ID: [0, 3]: Samples: 297(+69): T = 0.0017, K = 4, treeK = 14, [+0.1s]
# Train Error: 0.0042
# Test Error: 0.0044
# 50 -- ID: [0, 2]: Samples: 274(+75): T = 0.0026, K = 4, treeK = 16, [+0.1s]
# Train Error: 0.0035
# Test Error: 0.0036
# 51 -- ID: [0, 1]: Samples: 322(+68): T = 0.0021, K = 4, treeK = 18, [+0.1s]
# Train Error: 0.0030
# Test Error: 0.0033
# 52 -- ID: [0, 4]: Samples: 328(+75): T = 0.0017, K = 5, treeK = 20, [+0.1s]
# Train Error: 0.0028
# Test Error: 0.0032
# 53 -- ID: [0, 3]: Samples: 357(+60): T = 0.0017, K = 4, treeK = 20, [+0.1s]
# --- Maximum number of codevectors reached.
# ID: [0, 3]: Trained. Splitting..
# 54 -- ID: [0, 0]: Samples: 368(+94): T = 0.0017, K = 4, treeK = 21, [+0.1s]
# Train Error: 0.0027
# Test Error: 0.0031
# 55 -- ID: [0, 3, 2]: Samples: 24(+24): T = 0.0010, K = 1, treeK = 21, [+0.1s]
# Train Error: 0.0027
# Test Error: 0.0031
# 56 -- ID: [0, 3, 0]: Samples: 35(+35): T = 0.0010, K = 1, treeK = 21, [+0.1s]
# Train Error: 0.0027
# Test Error: 0.0031
# 57 -- ID: [0, 4]: Samples: 424(+96): T = 0.0013, K = 5, treeK = 21, [+0.1s]
# Train Error: 0.0027
# Test Error: 0.0030
# 58 -- ID: [0, 1]: Samples: 446(+124): T = 0.0021, K = 4, treeK = 21, [+0.2s]
# --- Maximum number of codevectors reached.
# ID: [0, 1]: Trained. Splitting..
# 59 -- ID: [0, 0]: Samples: 471(+103): T = 0.0017, K = 4, treeK = 21, [+0.1s]
# --- Maximum number of codevectors reached.
# ID: [0, 0]: Trained. Splitting..
# 60 -- ID: [0, 2]: Samples: 413(+139): T = 0.0026, K = 4, treeK = 21, [+0.2s]
# --- Maximum number of codevectors reached.
# ID: [0, 2]: Trained. Splitting..
# 61 -- ID: [0, 3, 2]: Samples: 58(+34): T = 0.0008, K = 1, treeK = 21, [+0.1s]
# Train Error: 0.0027
# Test Error: 0.0030
# 62 -- ID: [0, 3, 0]: Samples: 69(+34): T = 0.0008, K = 2, treeK = 22, [+0.1s]
# Train Error: 0.0026
# Test Error: 0.0029
# 63 -- ID: [0, 0, 0]: Samples: 29(+29): T = 0.0010, K = 2, treeK = 23, [+0.1s]
# Train Error: 0.0026
# Test Error: 0.0029
# 64 -- ID: [0, 4]: Samples: 530(+106): T = 0.0011, K = 5, treeK = 23, [+0.1s]
# Train Error: 0.0026
# Test Error: 0.0029
# 65 -- ID: [0, 1, 2]: Samples: 26(+26): T = 0.0010, K = 2, treeK = 24, [+0.1s]
# Train Error: 0.0026
# Test Error: 0.0029
# 66 -- ID: [0, 2, 1]: Samples: 26(+26): T = 0.0010, K = 2, treeK = 25, [+0.1s]
# Train Error: 0.0026
# Test Error: 0.0028
# 67 -- ID: [0, 1, 0]: Samples: 40(+40): T = 0.0010, K = 2, treeK = 26, [+0.2s]
# Train Error: 0.0026
# Test Error: 0.0029
# 68 -- ID: [0, 0, 1]: Samples: 50(+50): T = 0.0010, K = 2, treeK = 27, [+0.2s]
# Train Error: 0.0025
# Test Error: 0.0029
# 69 -- ID: [0, 1, 3]: Samples: 37(+37): T = 0.0010, K = 2, treeK = 28, [+0.2s]
# Train Error: 0.0024
# Test Error: 0.0028
# 70 -- ID: [0, 3, 2]: Samples: 94(+36): T = 0.0006, K = 2, treeK = 29, [+0.1s]
# Train Error: 0.0024
# Test Error: 0.0028
# 71 -- ID: [0, 0, 0]: Samples: 66(+37): T = 0.0008, K = 3, treeK = 30, [+0.1s]
# Train Error: 0.0023
# Test Error: 0.0028
# 72 -- ID: [0, 2, 2]: Samples: 38(+38): T = 0.0010, K = 2, treeK = 31, [+0.2s]
# Train Error: 0.0023
# Test Error: 0.0028
# 73 -- ID: [0, 3, 1]: Samples: 41(+41): T = 0.0010, K = 2, treeK = 32, [+0.4s]
# Train Error: 0.0023
# Test Error: 0.0027
# 74 -- ID: [0, 0, 2]: Samples: 42(+42): T = 0.0010, K = 2, treeK = 33, [+0.3s]
# Train Error: 0.0023
# Test Error: 0.0027
# 75 -- ID: [0, 3, 0]: Samples: 140(+71): T = 0.0006, K = 3, treeK = 34, [+0.2s]
# Train Error: 0.0022
# Test Error: 0.0027
# 76 -- ID: [0, 2, 0]: Samples: 52(+52): T = 0.0010, K = 2, treeK = 35, [+0.3s]
# Train Error: 0.0021
# Test Error: 0.0026
# 77 -- ID: [0, 3, 2]: Samples: 138(+44): T = 0.0005, K = 3, treeK = 36, [+0.1s]
# Train Error: 0.0021
# Test Error: 0.0026
# 78 -- ID: [0, 1, 2]: Samples: 64(+38): T = 0.0008, K = 3, treeK = 37, [+0.2s]
# Train Error: 0.0020
# Test Error: 0.0025
# 79 -- ID: [0, 4]: Samples: 706(+176): T = 0.0011, K = 5, treeK = 37, [+0.3s]
# --- Maximum number of codevectors reached.
# ID: [0, 4]: Trained. Splitting..
# 80 -- ID: [0, 2, 3]: Samples: 49(+49): T = 0.0010, K = 2, treeK = 38, [+0.4s]
# Train Error: 0.0020
# Test Error: 0.0025
# 81 -- ID: [0, 1, 0]: Samples: 89(+49): T = 0.0008, K = 3, treeK = 39, [+0.3s]
# Train Error: 0.0019
# Test Error: 0.0024
# 82 -- ID: [0, 1, 1]: Samples: 50(+50): T = 0.0010, K = 2, treeK = 40, [+0.5s]
# Train Error: 0.0019
# Test Error: 0.0024
# 83 -- ID: [0, 2, 1]: Samples: 74(+48): T = 0.0008, K = 2, treeK = 40, [+0.3s]
# Train Error: 0.0019
# Test Error: 0.0024
# 84 -- ID: [0, 1, 3]: Samples: 100(+63): T = 0.0008, K = 4, treeK = 42, [+0.3s]
# Train Error: 0.0018
# Test Error: 0.0023
# 85 -- ID: [0, 0, 0]: Samples: 128(+62): T = 0.0006, K = 4, treeK = 43, [+0.3s]
# Train Error: 0.0018
# Test Error: 0.0023
# 86 -- ID: [0, 0, 1]: Samples: 127(+77): T = 0.0008, K = 4, treeK = 45, [+0.3s]
# Train Error: 0.0017
# Test Error: 0.0023
# 87 -- ID: [0, 3, 0]: Samples: 212(+72): T = 0.0005, K = 5, treeK = 47, [+0.2s]
# Train Error: 0.0017
# Test Error: 0.0022
# 88 -- ID: [0, 4, 0]: Samples: 45(+45): T = 0.0010, K = 1, treeK = 47, [+0.2s]
# Train Error: 0.0017
# Test Error: 0.0022
# 89 -- ID: [0, 3, 2]: Samples: 190(+52): T = 0.0004, K = 4, treeK = 48, [+0.2s]
# Train Error: 0.0017
# Test Error: 0.0022
# --- Minimum temperature reached. ---
# ID: [0, 3, 2]: Trained
# 90 -- ID: [0, 0, 2]: Samples: 89(+47): T = 0.0008, K = 3, treeK = 49, [+0.3s]
# Train Error: 0.0016
# Test Error: 0.0021
# 91 -- ID: [0, 2, 2]: Samples: 93(+55): T = 0.0008, K = 3, treeK = 50, [+0.4s]
# Train Error: 0.0015
# Test Error: 0.0021
# 92 -- ID: [0, 2, 0]: Samples: 111(+59): T = 0.0008, K = 3, treeK = 51, [+0.3s]
# Train Error: 0.0014
# Test Error: 0.0020
# 93 -- ID: [0, 4, 2]: Samples: 36(+36): T = 0.0010, K = 2, treeK = 52, [+0.3s]
# Train Error: 0.0014
# Test Error: 0.0020
# 94 -- ID: [0, 4, 0]: Samples: 92(+47): T = 0.0008, K = 1, treeK = 52, [+0.1s]
# Train Error: 0.0014
# Test Error: 0.0020
# 95 -- ID: [0, 4, 4]: Samples: 20(+20): T = 0.0010, K = 2, treeK = 53, [+0.3s]
# Train Error: 0.0014
# Test Error: 0.0020
# 96 -- ID: [0, 1, 2]: Samples: 122(+58): T = 0.0006, K = 3, treeK = 53, [+0.4s]
# Train Error: 0.0014
# Test Error: 0.0020
# *** Idle Codevector Pruned ***
# 97 -- ID: [0, 1, 0]: Samples: 165(+76): T = 0.0006, K = 4, treeK = 54, [+0.4s]
# Train Error: 0.0013
# Test Error: 0.0020
# 98 -- ID: [0, 0, 3]: Samples: 38(+38): T = 0.0010, K = 2, treeK = 55, [+0.8s]
# Train Error: 0.0013
# Test Error: 0.0020
# 99 -- ID: [0, 4, 3]: Samples: 40(+40): T = 0.0010, K = 2, treeK = 56, [+0.4s]
# Train Error: 0.0013
# Test Error: 0.0020
# 100 -- ID: [0, 2, 1]: Samples: 136(+62): T = 0.0006, K = 3, treeK = 57, [+0.4s]
# Train Error: 0.0013
# Test Error: 0.0018
# 101 -- ID: [0, 3, 0]: Samples: 296(+84): T = 0.0005, K = 5, treeK = 57, [+0.3s]
# --- Maximum number of codevectors reached.
# ID: [0, 3, 0]: Trained
# 102 -- ID: [0, 0, 0]: Samples: 205(+77): T = 0.0005, K = 5, treeK = 58, [+0.4s]
# Train Error: 0.0013
# Test Error: 0.0018
# 103 -- ID: [0, 4, 2]: Samples: 66(+30): T = 0.0008, K = 3, treeK = 59, [+0.2s]
# Train Error: 0.0012
# Test Error: 0.0018
# 104 -- ID: [0, 4, 0]: Samples: 143(+51): T = 0.0006, K = 2, treeK = 60, [+0.2s]
# Train Error: 0.0012
# Test Error: 0.0016
# 105 -- ID: [0, 1, 1]: Samples: 98(+48): T = 0.0008, K = 3, treeK = 61, [+0.5s]
# Train Error: 0.0011
# Test Error: 0.0016
# 106 -- ID: [0, 1, 3]: Samples: 200(+100): T = 0.0006, K = 4, treeK = 61, [+0.5s]
# Train Error: 0.0011
# Test Error: 0.0016
# 107 -- ID: [0, 0, 1]: Samples: 238(+111): T = 0.0008, K = 4, treeK = 61, [+0.5s]
# --- Maximum number of codevectors reached.
# ID: [0, 0, 1]: Trained
# *** Idle Codevector Pruned ***
# 108 -- ID: [0, 0, 2]: Samples: 142(+53): T = 0.0006, K = 3, treeK = 61, [+0.4s]
# Train Error: 0.0011
# Test Error: 0.0016
# 109 -- ID: [0, 3, 1]: Samples: 105(+64): T = 0.0008, K = 3, treeK = 62, [+0.8s]
# Train Error: 0.0010
# Test Error: 0.0015
# 110 -- ID: [0, 2, 3]: Samples: 128(+79): T = 0.0008, K = 3, treeK = 63, [+0.7s]
# Train Error: 0.0010
# Test Error: 0.0015
# 111 -- ID: [0, 2, 0]: Samples: 187(+76): T = 0.0006, K = 4, treeK = 64, [+0.5s]
# Train Error: 0.0010
# Test Error: 0.0015
# 112 -- ID: [0, 0, 0]: Samples: 276(+71): T = 0.0004, K = 5, treeK = 64, [+0.3s]
# Train Error: 0.0010
# Test Error: 0.0015
# --- Minimum temperature reached. ---
# ID: [0, 0, 0]: Trained
# 113 -- ID: [0, 4, 0]: Samples: 220(+77): T = 0.0005, K = 4, treeK = 66, [+0.2s]
# Train Error: 0.0009
# Test Error: 0.0014
# 114 -- ID: [0, 4, 3]: Samples: 80(+40): T = 0.0008, K = 3, treeK = 67, [+0.4s]
# Train Error: 0.0009
# Test Error: 0.0014
# *** Idle Codevector Pruned ***
# 115 -- ID: [0, 4, 2]: Samples: 102(+36): T = 0.0006, K = 2, treeK = 66, [+0.3s]
# Train Error: 0.0009
# Test Error: 0.0014
# 116 -- ID: [0, 4, 4]: Samples: 46(+26): T = 0.0008, K = 3, treeK = 67, [+0.5s]
# Train Error: 0.0009
# Test Error: 0.0014
# *** Idle Codevector Pruned ***
# 117 -- ID: [0, 2, 2]: Samples: 181(+88): T = 0.0006, K = 4, treeK = 68, [+0.6s]
# Train Error: 0.0008
# Test Error: 0.0014
# 118 -- ID: [0, 1, 2]: Samples: 202(+80): T = 0.0005, K = 4, treeK = 69, [+0.5s]
# Train Error: 0.0008
# Test Error: 0.0014
# 119 -- ID: [0, 1, 0]: Samples: 263(+98): T = 0.0006, K = 4, treeK = 69, [+0.5s]
# --- Maximum number of codevectors reached.
# ID: [0, 1, 0]: Trained
# 120 -- ID: [0, 2, 1]: Samples: 212(+76): T = 0.0005, K = 3, treeK = 69, [+0.5s]
# Train Error: 0.0008
# Test Error: 0.0014
# 121 -- ID: [0, 0, 2]: Samples: 199(+57): T = 0.0005, K = 4, treeK = 70, [+0.3s]
# Train Error: 0.0008
# Test Error: 0.0014
# 122 -- ID: [0, 4, 2]: Samples: 138(+36): T = 0.0005, K = 3, treeK = 71, [+0.2s]
# Train Error: 0.0008
# Test Error: 0.0014
# 123 -- ID: [0, 4, 0]: Samples: 310(+90): T = 0.0004, K = 5, treeK = 72, [+0.2s]
# Train Error: 0.0008
# Test Error: 0.0014
# --- Minimum temperature reached. ---
# ID: [0, 4, 0]: Trained
# 124 -- ID: [0, 1, 3]: Samples: 300(+100): T = 0.0005, K = 5, treeK = 73, [+0.4s]
# Train Error: 0.0008
# Test Error: 0.0014
# 125 -- ID: [0, 3, 1]: Samples: 151(+46): T = 0.0006, K = 4, treeK = 74, [+0.4s]
# Train Error: 0.0008
# Test Error: 0.0014
# 126 -- ID: [0, 0, 3]: Samples: 76(+38): T = 0.0008, K = 3, treeK = 75, [+0.7s]
# Train Error: 0.0008
# Test Error: 0.0013
# *** Idle Codevector Pruned ***
# 127 -- ID: [0, 4, 3]: Samples: 128(+48): T = 0.0006, K = 2, treeK = 74, [+0.3s]
# Train Error: 0.0008
# Test Error: 0.0013
# 128 -- ID: [0, 2, 0]: Samples: 272(+85): T = 0.0006, K = 4, treeK = 74, [+0.4s]
# --- Maximum number of codevectors reached.
# ID: [0, 2, 0]: Trained
# *** Idle Codevector Pruned ***
# 129 -- ID: [0, 1, 1]: Samples: 168(+70): T = 0.0006, K = 3, treeK = 74, [+0.6s]
# Train Error: 0.0007
# Test Error: 0.0013
# 130 -- ID: [0, 2, 1]: Samples: 272(+60): T = 0.0004, K = 4, treeK = 75, [+0.3s]
# Train Error: 0.0007
# Test Error: 0.0012
# --- Minimum temperature reached. ---
# ID: [0, 2, 1]: Trained
# 131 -- ID: [0, 4, 1]: Samples: 34(+34): T = 0.0010, K = 2, treeK = 76, [+1.2s]
# Train Error: 0.0007
# Test Error: 0.0012
# 132 -- ID: [0, 2, 3]: Samples: 207(+79): T = 0.0006, K = 5, treeK = 78, [+0.5s]
# Train Error: 0.0007
# Test Error: 0.0012
# 133 -- ID: [0, 4, 4]: Samples: 80(+34): T = 0.0006, K = 3, treeK = 78, [+0.4s]
# Train Error: 0.0007
# Test Error: 0.0012
# 134 -- ID: [0, 4, 2]: Samples: 189(+51): T = 0.0004, K = 3, treeK = 78, [+0.3s]
# Train Error: 0.0007
# Test Error: 0.0012
# --- Minimum temperature reached. ---
# ID: [0, 4, 2]: Trained
# 135 -- ID: [0, 2, 2]: Samples: 261(+80): T = 0.0006, K = 4, treeK = 78, [+0.4s]
# --- Maximum number of codevectors reached.
# ID: [0, 2, 2]: Trained
# 136 -- ID: [0, 4, 3]: Samples: 180(+52): T = 0.0005, K = 3, treeK = 79, [+0.3s]
# Train Error: 0.0007
# Test Error: 0.0012
# 137 -- ID: [0, 1, 2]: Samples: 330(+128): T = 0.0004, K = 5, treeK = 80, [+0.6s]
# Train Error: 0.0007
# Test Error: 0.0012
# --- Minimum temperature reached. ---
# ID: [0, 1, 2]: Trained
# 138 -- ID: [0, 1, 3]: Samples: 427(+127): T = 0.0005, K = 5, treeK = 80, [+0.4s]
# --- Maximum number of codevectors reached.
# ID: [0, 1, 3]: Trained
# 139 -- ID: [0, 0, 2]: Samples: 304(+105): T = 0.0005, K = 4, treeK = 80, [+0.5s]
# --- Maximum number of codevectors reached.
# ID: [0, 0, 2]: Trained
# *** Idle Codevector Pruned ***
# 140 -- ID: [0, 4, 4]: Samples: 109(+29): T = 0.0005, K = 3, treeK = 80, [+0.3s]
# Train Error: 0.0007
# Test Error: 0.0012
# 141 -- ID: [0, 2, 3]: Samples: 280(+73): T = 0.0005, K = 5, treeK = 80, [+0.3s]
# Train Error: 0.0007
# Test Error: 0.0012
# 142 -- ID: [0, 3, 1]: Samples: 229(+78): T = 0.0005, K = 5, treeK = 81, [+0.5s]
# Train Error: 0.0007
# Test Error: 0.0012
# 143 -- ID: [0, 1, 1]: Samples: 258(+90): T = 0.0005, K = 3, treeK = 81, [+0.5s]
# Train Error: 0.0007
# Test Error: 0.0012
# 144 -- ID: [0, 4, 3]: Samples: 234(+54): T = 0.0004, K = 4, treeK = 82, [+0.2s]
# Train Error: 0.0007
# Test Error: 0.0012
# --- Minimum temperature reached. ---
# ID: [0, 4, 3]: Trained
# 145 -- ID: [0, 4, 4]: Samples: 133(+24): T = 0.0004, K = 3, treeK = 82, [+0.2s]
# Train Error: 0.0007
# Test Error: 0.0012
# --- Minimum temperature reached. ---
# ID: [0, 4, 4]: Trained
# *** Idle Codevector Pruned ***
# 146 -- ID: [0, 0, 3]: Samples: 132(+56): T = 0.0006, K = 4, treeK = 83, [+0.6s]
# Train Error: 0.0007
# Test Error: 0.0011
# 147 -- ID: [0, 2, 3]: Samples: 337(+57): T = 0.0004, K = 5, treeK = 83, [+0.2s]
# Train Error: 0.0007
# Test Error: 0.0011
# --- Minimum temperature reached. ---
# ID: [0, 2, 3]: Trained
# 148 -- ID: [0, 3, 3]: Samples: 61(+61): T = 0.0010, K = 2, treeK = 84, [+2.3s]
# Train Error: 0.0007
# Test Error: 0.0011
# 149 -- ID: [0, 4, 1]: Samples: 66(+32): T = 0.0008, K = 3, treeK = 85, [+0.6s]
# Train Error: 0.0006
# Test Error: 0.0011
# 150 -- ID: [0, 3, 1]: Samples: 307(+78): T = 0.0005, K = 5, treeK = 85, [+0.3s]
# --- Maximum number of codevectors reached.
# ID: [0, 3, 1]: Trained
# 151 -- ID: [0, 0, 3]: Samples: 163(+31): T = 0.0005, K = 5, treeK = 86, [+0.2s]
# Train Error: 0.0006
# Test Error: 0.0011
# 152 -- ID: [0, 1, 1]: Samples: 355(+97): T = 0.0004, K = 4, treeK = 87, [+0.3s]
# Train Error: 0.0006
# Test Error: 0.0011
# --- Minimum temperature reached. ---
# ID: [0, 1, 1]: Trained
# 153 -- ID: [0, 0, 3]: Samples: 177(+14): T = 0.0004, K = 5, treeK = 87, [+0.1s]
# Train Error: 0.0006
# Test Error: 0.0011
# --- Minimum temperature reached. ---
# ID: [0, 0, 3]: Trained
# *** Idle Codevector Pruned ***
# 154 -- ID: [0, 4, 1]: Samples: 96(+30): T = 0.0006, K = 3, treeK = 87, [+0.2s]
# Train Error: 0.0006
# Test Error: 0.0011
# 155 -- ID: [0, 4, 1]: Samples: 112(+16): T = 0.0005, K = 3, treeK = 87, [+0.1s]
# Train Error: 0.0006
# Test Error: 0.0011
# 156 -- ID: [0, 4, 1]: Samples: 124(+12): T = 0.0004, K = 3, treeK = 87, [+0.1s]
# Train Error: 0.0006
# Test Error: 0.0011
# --- Minimum temperature reached. ---
# ID: [0, 4, 1]: Trained
# 157 -- ID: [0, 3, 3]: Samples: 114(+53): T = 0.0008, K = 3, treeK = 88, [+0.5s]
# Train Error: 0.0006
# Test Error: 0.0011
# *** Idle Codevector Pruned ***
# 158 -- ID: [0, 3, 3]: Samples: 129(+15): T = 0.0006, K = 3, treeK = 88, [+0.1s]
# Train Error: 0.0006
# Test Error: 0.0011
# 159 -- ID: [0, 3, 3]: Samples: 137(+8): T = 0.0005, K = 3, treeK = 88, [+0.0s]
# Train Error: 0.0006
# Test Error: 0.0011
# 160 -- ID: [0, 3, 3]: Samples: 143(+6): T = 0.0004, K = 3, treeK = 88, [+0.0s]
# Train Error: 0.0006
# Test Error: 0.0011
# --- Minimum temperature reached. ---
# ID: [0, 3, 3]: Trained
# *** ODA ***
# Ave. Distortion: 0.0006232193361260321
# Ave. Distortion: 0.0010720428809586386
# Running time: 3.7s

# %% [markdown]
# ## Plot Training Curve

# %%
if clf.keepscore>1 and plot_curves:
    oPlot = FlowLayout()
    ax = clf.plot_curve('.', show = False, save = False)
    oPlot.add_plot(ax)
    oPlot.PassHtmlToCell()
# Out:
#         <style>
#         .floating-box {
#         display: inline-block;
#         margin: 10px;
#         border: 3px solid #888888;
#         }
#         </style>
#         <div class="floating-box"><img src="data:image/png;base64,...
# "></div>

# %% [markdown]
# ## Show Domain

# %%
show_domain = True

if show_domain:
    print('*** Plotting Domain ***')
    if len(res)<2:
        oPlot = FlowLayout()
        for i in [1,3,7]:
            ax = demo_domain.show_instance(clf=clf, instance = i, res=res, plot_fig=False, save_fig = False)
            oPlot.add_plot(ax)
        oPlot.PassHtmlToCell()
    else:
        axs = demo_domain.show_resolutions(clf=clf, res=res, plot_fig=False, save_fig = False)
        oPlot = FlowLayout()
        for ax in axs:
            oPlot.add_plot(ax)
        oPlot.PassHtmlToCell()
        
print('*** All Done ***')
# Out:
# *** Plotting Domain ***
#         <style>
#         .floating-box {
#         display: inline-block;
#         margin: 10px;
#         border: 3px solid #888888;
#         }
#         </style>
#         <div class="floating-box"><img src="data:image/png;base64,...
# "></div><div class="floating-box"><img src="data:image/png;base64,...
# "></div><div class="floating-box"><img src="data:image/png;base64,...
# "></div>
# *** All Done ***

# %% [markdown]
# # Takeaways:
#
# ## [1] Reduction in time complexity $O(|C|^2 + |C| \log_{|C|} K) < O(K^2)$
# - $|C|<<K$: number of children nodes
# - typically $|C|>2$, which implies $\log_{|C|} K<\log_{2} K$ ($|C|=2$ in binary trees)
# - Compare 3.6s (Tree-Structured ODA) to ~30s (ODA)
#
# ## [2] Hierarchical Partitioning
# - Reduces prediction time to $O(|C| \log_{|C|} K) < O(K^2)$
# - Creates hierarchically structured knowledge representation useful in attention mechanisms, progressive compression, etc.
